# %%
import numpy as np
import pandas as pd
from itertools import product
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

import gurobipy as grb
from gurobipy import GRB

# %% [markdown]
# # Input Problem Parameters

# %% [markdown]
# ## Import du problème

# %%
from utils.extract_parameters import extract_parameters
from utils.define_nums import define_nums
from utils.domination_3D import liste_dominants, graph_dominant

# %%
################################
######## TO DO #################
################################

# choose taille among: "small", "medium", "large"
taille = "medium"

## To change according to preference system
input_projet_max = 15
input_longueur_max = 21

# %%
################################
######## DO NOT CHANGE #########
################################
map_employe_indice, map_job_indice, map_qualif_indice, conge, qualif, d, p, b, besoin = extract_parameters(taille)
nombre_employes, horizon, nombre_qualifs, nombre_projets = define_nums(conge, qualif, d, p, b, besoin)

# %% [markdown]
# ## Définissons les paramètres

# %%
## u_j, le projet j est réalisé
u_shape = nombre_projets

## x_i_j_k_n, l'employé k travaille sur le projet j avec la qualif i
## au jour n
x_shape = [(i,j,k, n) for i in range(nombre_qualifs) for j in range(nombre_projets) for k in range(nombre_employes) for n in range(horizon)]

## t_k_j, l'employé k travaille sur le projet j
t_shape = [(i,j) for i in range(nombre_employes) for j in range(nombre_projets)]

## begin_j, la date de début effective
begin_shape = nombre_projets

## end_j, la date de fin effective = date de livraison du projet j
end_shape = nombre_projets

## delay_j, le nombre de jours de retard par projet j
delay_shape = nombre_projets

## longueur_j, la longueur du projet j
longueur_shape = nombre_projets

## projet_par_employe_k, le nombre de projet par employe
projet_par_employe_shape = nombre_employes

# majorant pour la contrainte de couverture
maj = max([besoin[i][j] for j in range(nombre_projets) for i in range(nombre_qualifs)]) + 1

# si le projet j est travaillé au jour n
job_in_process_shape = [(j, n) for j in range(nombre_projets) for n in range(horizon)]

# %% [markdown]
# # Model deployment

# %% [markdown]
# ## Add the variables

# %%
model = grb.Model("Planning")

# L'affectation du planning, la variable clé
x = model.addVars(x_shape, vtype=GRB.BINARY, name="x")

## Les dates de fin des projets
dateFin = model.addVars(end_shape, lb = 0, ub = horizon, name = "dateFin")

## Les dates de début des projets
dateDebut = model.addVars(begin_shape, lb = 0, ub = horizon, name = "dateDebut")

## Le nombre de jours de delai
delay = model.addVars(delay_shape, lb = 0, ub = horizon, name = "delay")

## Les longueurs des projets
longueur = model.addVars(longueur_shape, lb = 0, ub = horizon, name = "longueur")

## Nombre de projet par employé
projet_par_employe = model.addVars(projet_par_employe_shape, lb = 0, ub = nombre_projets, name = "projet_par_employe")

## L'affectation sur un projet d'un employé
affectation = model.addVars(t_shape, vtype = GRB.BINARY, name = "affectation")

## La réalisation ou non d'un projet
u = model.addVars(u_shape, vtype = GRB.BINARY, name="u")

## Verification du projet
job_in_process = model.addVars(job_in_process_shape, vtype = GRB.BINARY, name = "job_in_process")

# %%
# Update le modele pour confirmer la création des variables
model.update()

# %% [markdown]
# ## Add constraints

# %%
for i in range(nombre_qualifs):
    for j in range(nombre_projets):
        for k in range(nombre_employes):
            for n in range(horizon):
                ## La qualification du personnel
                model.addConstr( x[i,j,k,n] <= qualif[i][k], name="QualificationPersonnel[{0}{1}{2}{3}]".format(i,j,k,n))
                model.addConstr( x[i,j,k,n] <= (besoin[i][j] >=1), name = "BesoinQualifPersonnel[{0}{1}{2}{3}]".format(i,j,k,n))
                ## Contraintes des congés
                model.addConstr( x[i,j,k,n] <= conge[k][n], name=f"CongesPersonnel[{i}{j}{k}{n}]")
        
        ## Contrainte d'unicité de réalisation d'un projet
        model.addConstr(grb.quicksum(grb.quicksum(x[i,j,k,n] for n in range(horizon)) for k in range(nombre_employes)) == besoin[i][j]*u[j], name=f"UniciteRealisation[{i}{j}]")

## Unicité de l'affectation quotidienne
for k in range(nombre_employes):
    for n in range(horizon):
        model.addConstr(grb.quicksum(grb.quicksum(x[i,j,k,n] for j in range(nombre_projets)) for i in range(nombre_qualifs)) <= 1, name=f"UniciteAffectation[{k}{n}]")
       
for j in range(nombre_projets):
    for n in range(horizon):
        model.addConstrs(((job_in_process[j,n] >= x[i,j,k,n]) for i in range(nombre_qualifs) for k in range(nombre_employes)), name=f"ContrainteJobInProcess[{j}{n}]")
    # start date
    model.addConstrs(((dateDebut[j] <= job_in_process[j,n]*n) for n in range(horizon)), name = f"ContrainteDateDebut[{j}]")

    # end date
    model.addConstrs(((job_in_process[j,n]*n <= dateFin[j]) for n in range(horizon)), name=f"FinProjet[{j}]")

    ## longueur
    model.addConstr(longueur[j] == dateFin[j] - dateDebut[j], name=f"LongueurProjet[{j}]")

    ## delay
    model.addConstr(delay[j] >= dateFin[j] - (d[j] - 1), name=f"DelaiProjet_difference[{j}]")    

## projet_par_employe
for k in range(nombre_employes):
    model.addConstr(projet_par_employe[k] == grb.quicksum( affectation[k,j] for j in range(nombre_projets)), name=f"FinProjet[{j}]")
    
## Contrainte de l'affectation à un projet selon les jours de travail
for k in range(nombre_employes):
    for j in range(nombre_projets):
        model.addConstr(affectation[k,j] <= grb.quicksum(grb.quicksum(x[i,j,k,n] for i in range(nombre_qualifs)) for n in range(horizon)), name=f"AffectationProjetQuicksum[{k}{j}]")

# %% [markdown]
# ## Fonctions d'export

# %%
# Edt des employés et le détail de la réalisation de chaque tâche (de façon ordonnée)
def create_schedule(model):
    schedules = []
    tasks_performances = []
    for i in range(nombre_qualifs):
        for j in range(nombre_projets):
            for k in range(nombre_employes):
                for n in range(horizon):
                    v = model.getVarByName(f"x[{i},{j},{k},{n}]")
                    if int(v.x) == 1:
                        schedules.append((map_employe_indice[k], n+1, map_job_indice[j], map_qualif_indice[i]))
    schedules.sort()
    return(schedules)

# %%
def create_df(model,i):
    schedules = create_schedule(model)
    df = pd.DataFrame(schedules, columns=['Nom', 'Jour', 'Projet', 'Qualification'])
    df['Affectation'] = df[['Projet', 'Qualification']].values.tolist()

    df = df.pivot(index=['Nom'], 
                        columns=['Jour'],
                        values=['Affectation'])

    for k in range(nombre_employes):
        for n in range(horizon):
            name = map_employe_indice[k]
            if not conge[k][n]:
                df.loc[(df.index==name),("Affectation",n+1)] = 'En congé'

    df.fillna("Non affecté.e", inplace=True)
    df.to_excel("results/final/"+taille+"/"+str(i)+".xlsx")

# %% [markdown]
# ## Fonctions objectif et optimisation

# %%
## bénéfice total
benefice_tot = grb.quicksum( (b[j]*u[j] - delay[j]*p[j]) for j in range(nombre_projets) )

# Nombre de projet maximum par personne
projet_max = model.addVar(lb= 0, ub=nombre_projets, name="projet_max")
model.addConstrs(projet_max>=projet_par_employe[k] for k in range(nombre_employes))

# Compacité des projets
longueur_max = model.addVar(lb = 0, ub=horizon, name="longueur_max")
model.addConstrs(longueur_max>=longueur[j] for j in range(nombre_projets))
model.addConstr(longueur_max==input_longueur_max)

for i in range(input_projet_max-1, 0, -1):
    model.addConstr(projet_max<=i)

    model.ModelSense = GRB.MAXIMIZE
    model.setObjective(benefice_tot)

    model.update()

    model.optimize()

    create_df(model, i)
    print(model.objVal)
    
    model.reset()
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67052 rows, 16987 columns and 133596 nonzeros
# Model fingerprint: 0xe61b4d76
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66576 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 0.96 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67053 rows, 16987 columns and 133597 nonzeros
# Model fingerprint: 0xae5fd859
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66577 rows and 15576 columns
# Presolve time: 0.12s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 0.93 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67054 rows, 16987 columns and 133598 nonzeros
# Model fingerprint: 0x27ab321c
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66578 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 0.91 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67055 rows, 16987 columns and 133599 nonzeros
# Model fingerprint: 0x5b8f9bbe
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66579 rows and 15576 columns
# Presolve time: 0.09s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 0.93 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67056 rows, 16987 columns and 133600 nonzeros
# Model fingerprint: 0xf1b78bea
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66580 rows and 15576 columns
# Presolve time: 0.06s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.00 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67057 rows, 16987 columns and 133601 nonzeros
# Model fingerprint: 0xe727fe29
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66581 rows and 15576 columns
# Presolve time: 0.12s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.13 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67058 rows, 16987 columns and 133602 nonzeros
# Model fingerprint: 0x0fc52b47
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66582 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.03 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67059 rows, 16987 columns and 133603 nonzeros
# Model fingerprint: 0x882a930c
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66583 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.02 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67060 rows, 16987 columns and 133604 nonzeros
# Model fingerprint: 0x421a805a
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66584 rows and 15576 columns
# Presolve time: 0.08s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.16 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67061 rows, 16987 columns and 133605 nonzeros
# Model fingerprint: 0xd46e7865
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66585 rows and 15576 columns
# Presolve time: 0.13s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.04 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67062 rows, 16987 columns and 133606 nonzeros
# Model fingerprint: 0x421e9e1c
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66586 rows and 15576 columns
# Presolve time: 0.09s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.20 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67063 rows, 16987 columns and 133607 nonzeros
# Model fingerprint: 0xf5beac50
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66587 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.06 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67064 rows, 16987 columns and 133608 nonzeros
# Model fingerprint: 0x8f83b74c
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66588 rows and 15576 columns
# Presolve time: 0.08s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.07 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 1.07 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67065 rows, 16987 columns and 133609 nonzeros
# Model fingerprint: 0x63f49d9a
# Variable types: 67 continuous, 16920 integer (16920 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 7e+01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 66589 rows and 15576 columns
# Presolve time: 0.07s
# Presolved: 476 rows, 1411 columns, 3458 nonzeros
# Variable types: 0 continuous, 1411 integer (1397 binary)
#
# Root relaxation: objective 4.285904e+02, 1061 iterations, 0.06 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  428.59042    0  148   -0.00000  428.59042      -     -    0s
# H    0     0                     383.0000000  428.59042  11.9%     -    0s
#      0     0  425.09164    0  126  383.00000  425.09164  11.0%     -    0s
# H    0     0                     404.0000000  425.09164  5.22%     -    0s
#      0     0  425.01383    0  127  404.00000  425.01383  5.20%     -    0s
#      0     0  423.73802    0  167  404.00000  423.73802  4.89%     -    0s
#      0     0  423.73802    0  157  404.00000  423.73802  4.89%     -    0s
#      0     2  423.73802    0  156  404.00000  423.73802  4.89%     -    0s
# H   35    40                     407.0000000  422.73559  3.87%  92.1    0s
# *   91    97              23     409.0000000  422.73559  3.36%  50.2    0s
# *  151   127              27     413.0000000  420.69084  1.86%  39.6    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 19
#   Clique: 12
#   MIR: 6
#   Zero half: 4
#   RLT: 27
#   Relax-and-lift: 32
#
# Explored 431 nodes (16903 simplex iterations) in 0.98 seconds (0.70 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 413 409 407 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.130000000000e+02, best bound 4.130000000000e+02, gap 0.0000%
# 413.0
# Discarded solution information

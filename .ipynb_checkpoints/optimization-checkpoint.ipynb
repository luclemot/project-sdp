# %%
import numpy as np
import pandas as pd
from itertools import product
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

import gurobipy as grb
from gurobipy import GRB

# %% [markdown]
# # Input Problem Parameters

# %% [markdown]
# ## Import du problème

# %%
from utils.extract_parameters import extract_parameters

################################
######## TO DO #################
################################

# choose taille among: "small", "medium", "large"
taille = "small"

# %%
################################
######## DO NOT CHANGE #########
################################
map_employe_indice, map_job_indice, map_qualif_indice, conge, qualif, d, p, b, besoin = extract_parameters(taille)

# %%
print("conge : ",conge)
print("qualif : ",qualif)
print("date livraison : ",d)
print("pénalité : ",p)
print("bénéfice : ",b)
print("besoin : ",besoin)
# Out:
# conge :  [[1, 1, 1, 1, 1], [0, 1, 1, 1, 1], [1, 0, 1, 1, 1]]
# qualif :  [[1, 1, 0], [1, 1, 0], [1, 0, 1]]
# date livraison :  [3, 3, 4, 3, 5]
# pénalité :  [3, 3, 3, 3, 3]
# bénéfice :  [20, 15, 15, 20, 10]
# besoin :  [[1, 1, 1, 0, 0], [1, 2, 0, 2, 0], [1, 0, 2, 1, 2]]

# %% [markdown]
# ## Définissons les paramètres

# %%
from utils.define_nums import define_nums

nombre_employes, horizon, nombre_qualifs, nombre_projets = define_nums(conge, qualif, d, p, b, besoin)

# %%
print("nombre_employes : ",nombre_employes)
print("horizon : ",horizon)
print("nombre_qualifs : ",nombre_qualifs)
print("nombre_projets : ",nombre_projets)
# Out:
# nombre_employes :  3
# horizon :  5
# nombre_qualifs :  3
# nombre_projets :  5

# %%
## u_j, le projet j est réalisé
u_shape = nombre_projets

## x_i_j_k_n, l'employé k travaille sur le projet j avec la qualif i
## au jour n
x_shape = [(i,j,k, n) for i in range(nombre_qualifs) for j in range(nombre_projets) for k in range(nombre_employes) for n in range(horizon)]

## t_k_j, l'employé k travaille sur le projet j
t_shape = [(i,j) for i in range(nombre_employes) for j in range(nombre_projets)]

## begin_j, la date de début effective
begin_shape = nombre_projets

## end_j, la date de fin effective = date de livraison du projet j
end_shape = nombre_projets

## delay_j, le nombre de jours de retard par projet j
delay_shape = nombre_projets

## longueur_j, la longueur du projet j
longueur_shape = nombre_projets

## projet_par_employe_k, le nombre de projet par employe
projet_par_employe_shape = nombre_employes

# majorant pour la contrainte de couverture
maj = max([besoin[i][j] for j in range(nombre_projets) for i in range(nombre_qualifs)]) + 1

# si le projet j est travaillé au jour n
job_in_process_shape = [(j, n) for j in range(nombre_projets) for n in range(horizon)]

# %% [markdown]
# # Model deployment

# %% [markdown]
# ## Add the variables

# %%
model = grb.Model("Planning")

# L'affectation du planning, la variable clé
x = model.addVars(x_shape, vtype=GRB.BINARY, name="x")

## Les dates de fin des projets
dateFin = model.addVars(end_shape, lb = 0, ub = horizon, name = "dateFin")

## Les dates de début des projets
dateDebut = model.addVars(begin_shape, lb = 0, ub = horizon, name = "dateDebut")

## Le nombre de jours de delai
delay = model.addVars(delay_shape, lb = 0, ub = horizon, name = "delay")

## Les longueurs des projets
longueur = model.addVars(longueur_shape, lb = 0, ub = horizon, name = "longueur")

## Nombre de projet par employé
projet_par_employe = model.addVars(projet_par_employe_shape, lb = 0, ub = nombre_projets, name = "projet_par_employe")

## L'affectation sur un projet d'un employé
affectation = model.addVars(t_shape, vtype = GRB.BINARY, name = "affectation")

## La réalisation ou non d'un projet
u = model.addVars(u_shape, vtype = GRB.BINARY, name="u")

## Verification du projet
job_in_process = model.addVars(job_in_process_shape, vtype = GRB.BINARY, name = "job_in_process")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-29

# %%
# Update le modele pour confirmer la création des variables
model.update()

# %% [markdown]
# ## Add constraints

# %%
for i in range(nombre_qualifs):
    for j in range(nombre_projets):
        for k in range(nombre_employes):
            for n in range(horizon):
                ## La qualification du personnel
                model.addConstr( x[i,j,k,n] <= qualif[i][k], name="QualificationPersonnel[{0}{1}{2}{3}]".format(i,j,k,n))
                model.addConstr( x[i,j,k,n] <= (besoin[i][j] >=1), name = "BesoinQualifPersonnel[{0}{1}{2}{3}]".format(i,j,k,n))
                ## Contraintes des congés
                model.addConstr( x[i,j,k,n] <= conge[k][n], name=f"CongesPersonnel[{i}{j}{k}{n}]")
        
        ## Contrainte d'unicité de réalisation d'un projet
        model.addConstr(grb.quicksum(grb.quicksum(x[i,j,k,n] for n in range(horizon)) for k in range(nombre_employes)) == besoin[i][j]*u[j], name=f"UniciteRealisation[{i}{j}]")

        ## Couverture des qualifications
        # model.addConstr( grb.quicksum(grb.quicksum(x[i,j,k,n] for n in range(horizon)) for k in range(nombre_employes)) - besoin[i][j] >= maj*(1-u[j]), name=f"CouvertureQualificationsInf[{i}{j}]") 


## Unicité de l'affectation quotidienne
for k in range(nombre_employes):
    for n in range(horizon):
        model.addConstr(grb.quicksum(grb.quicksum(x[i,j,k,n] for j in range(nombre_projets)) for i in range(nombre_qualifs)) <= 1, name=f"UniciteAffectation[{k}{n}]")

        
for j in range(nombre_projets):
    for n in range(horizon):
        model.addConstrs(((job_in_process[j,n] >= x[i,j,k,n]) for i in range(nombre_qualifs) for k in range(nombre_employes)), name=f"ContrainteJobInProcess[{j}{n}]")
    # start date
    model.addConstrs(((dateDebut[j] <= job_in_process[j,n]*n) for n in range(horizon)), name = f"ContrainteDateDebut[{j}]")

    # end date
    model.addConstrs(((job_in_process[j,n]*n <= dateFin[j]) for n in range(horizon)), name=f"FinProjet[{j}]")

    ## longueur
    model.addConstr(longueur[j] == dateFin[j] - dateDebut[j], name=f"LongueurProjet[{j}]")

    ## delay
    model.addConstr(delay[j] >= dateFin[j] - (d[j] - 1), name=f"DelaiProjet_difference[{j}]")    

## projet_par_employe
for k in range(nombre_employes):
    model.addConstr(projet_par_employe[k] == grb.quicksum( affectation[k,j] for j in range(nombre_projets)), name=f"FinProjet[{j}]")
    
    
## Contrainte de l'affectation à un projet selon les jours de travail
for k in range(nombre_employes):
    for j in range(nombre_projets):
        model.addConstr(affectation[k,j] <= grb.quicksum(grb.quicksum(x[i,j,k,n] for i in range(nombre_qualifs)) for n in range(horizon)), name=f"AffectationProjetQuicksum[{k}{j}]")

# %% [markdown]
# ## Fonctions objectif

# %%
## bénéfice total
benefice_tot = grb.quicksum( (b[j]*u[j] - delay[j]*p[j]) for j in range(nombre_projets) )

## Lignes pour optimiser le modèles
## sur le bénéfice total seulement

# model.ModelSense = GRB.MAXIMIZE
# model.setObjective(benefice_tot)
# model.ModelSense = GRB.MAXIMIZE

# %%
# Lignes pour optimiser le problème suivant
## les trois fonctions objectif voulues

# Nombre de projet maximum par personne
projet_max = model.addVar(lb= 0, ub=nombre_projets, name="projet_max")
model.addConstrs(projet_max>=projet_par_employe[k] for k in range(nombre_employes))

# Compacité des projets
longueur_max = model.addVar(lb = 0, ub=horizon, name="longueur_max")
model.addConstrs(longueur_max>=longueur[j] for j in range(nombre_projets))
# Out:
# {0: <gurobi.Constr *Awaiting Model Update*>,
#  1: <gurobi.Constr *Awaiting Model Update*>,
#  2: <gurobi.Constr *Awaiting Model Update*>,
#  3: <gurobi.Constr *Awaiting Model Update*>,
#  4: <gurobi.Constr *Awaiting Model Update*>}

# %%
model.update()

# %%
res = pd.DataFrame(columns = ["Benefice", "longueur max", "projets max"])

for l in range(horizon-1, 0 , -1):
    for p in range(nombre_projets-1, 0, -1):
        # contrainte sur la longueur des projets
        model.addConstr(longueur_max<=l)
        # contrainte sur le nombre de projets
        model.addConstr(projet_max<=p)

        model.ModelSense = GRB.MAXIMIZE
        model.setObjective(benefice_tot)
        model.ModelSense = GRB.MAXIMIZE
        model.optimize()

        res.loc[len(res)] = [model.objVal, int(longueur_max.x), int(projet_max.x)]
        
        model.resetParams()
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1018 rows, 295 columns and 1976 nonzeros
# Model fingerprint: 0x6790b0ab
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 966 rows and 190 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 105 columns, 270 nonzeros
# Variable types: 0 continuous, 105 integer (102 binary)
# Found heuristic solution: objective 20.0000000
#
# Root relaxation: objective 7.200000e+01, 79 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   16   20.00000   72.00000   260%     -    0s
# H    0     0                      62.0000000   72.00000  16.1%     -    0s
#      0     0   67.00000    0   16   62.00000   67.00000  8.06%     -    0s
# H    0     0                      64.0000000   66.72222  4.25%     -    0s
# H    0     0                      65.0000000   66.72222  2.65%     -    0s
#      0     0   66.72222    0   36   65.00000   66.72222  2.65%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 1
#   Clique: 2
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (170 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 65 64 62 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1020 rows, 295 columns and 1978 nonzeros
# Model fingerprint: 0x7738f755
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 65 (0.01s)
# Loaded MIP start from previous solve with objective 65
#
# Presolve removed 968 rows and 192 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 103 columns, 265 nonzeros
# Variable types: 0 continuous, 103 integer (100 binary)
#
# Root relaxation: objective 7.200000e+01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   19   65.00000   72.00000  10.8%     -    0s
#      0     0 infeasible    0        65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 1
#   MIR: 1
#   Zero half: 4
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (148 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 65
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1022 rows, 295 columns and 1980 nonzeros
# Model fingerprint: 0x4f874483
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 65 (0.01s)
# Loaded MIP start from previous solve with objective 65
#
# Presolve removed 970 rows and 192 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 103 columns, 265 nonzeros
# Variable types: 0 continuous, 103 integer (100 binary)
#
# Root relaxation: objective 7.200000e+01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   19   65.00000   72.00000  10.8%     -    0s
#      0     0 infeasible    0        65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 1
#   MIR: 1
#   Zero half: 4
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (148 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 65
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1024 rows, 295 columns and 1982 nonzeros
# Model fingerprint: 0xf5610caf
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 65 (0.01s)
# Loaded MIP start from previous solve with objective 65
#
# Presolve removed 972 rows and 192 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 103 columns, 265 nonzeros
# Variable types: 0 continuous, 103 integer (100 binary)
#
# Root relaxation: objective 7.200000e+01, 76 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   19   65.00000   72.00000  10.8%     -    0s
#      0     0 infeasible    0        65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Clique: 1
#   MIR: 1
#   Zero half: 4
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (148 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 65
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1026 rows, 295 columns and 1984 nonzeros
# Model fingerprint: 0x41e685bf
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Found heuristic solution: objective -0.0000000
# Presolve removed 996 rows and 217 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 78 columns, 180 nonzeros
# Variable types: 0 continuous, 78 integer (78 binary)
# Found heuristic solution: objective 20.0000000
#
# Root relaxation: objective 6.000000e+01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.00000    0    1   20.00000   60.00000   200%     -    0s
# H    0     0                      55.0000000   60.00000  9.09%     -    0s
#      0     0   60.00000    0    7   55.00000   60.00000  9.09%     -    0s
#      0     0   55.00000    0    3   55.00000   55.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 1
#   Zero half: 1
#
# Explored 1 nodes (62 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 55 20 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.500000000000e+01, best bound 5.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1028 rows, 295 columns and 1986 nonzeros
# Model fingerprint: 0x3eee421d
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 55 (0.01s)
# Loaded MIP start from previous solve with objective 55
#
# Presolve removed 998 rows and 217 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 78 columns, 180 nonzeros
# Variable types: 0 continuous, 78 integer (78 binary)
#
# Root relaxation: objective 6.000000e+01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.00000    0    1   55.00000   60.00000  9.09%     -    0s
#      0     0   60.00000    0    7   55.00000   60.00000  9.09%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Zero half: 1
#
# Explored 1 nodes (51 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.500000000000e+01, best bound 5.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1030 rows, 295 columns and 1988 nonzeros
# Model fingerprint: 0xcca1edd9
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 55 (0.01s)
# Loaded MIP start from previous solve with objective 55
#
# Presolve removed 1000 rows and 217 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 78 columns, 180 nonzeros
# Variable types: 0 continuous, 78 integer (78 binary)
#
# Root relaxation: objective 6.000000e+01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.00000    0    1   55.00000   60.00000  9.09%     -    0s
#      0     0   60.00000    0    7   55.00000   60.00000  9.09%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Zero half: 1
#
# Explored 1 nodes (51 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.500000000000e+01, best bound 5.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1032 rows, 295 columns and 1990 nonzeros
# Model fingerprint: 0xe7a12312
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 55 (0.01s)
# Loaded MIP start from previous solve with objective 55
#
# Presolve removed 1002 rows and 217 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 78 columns, 180 nonzeros
# Variable types: 0 continuous, 78 integer (78 binary)
#
# Root relaxation: objective 6.000000e+01, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   60.00000    0    1   55.00000   60.00000  9.09%     -    0s
#      0     0   60.00000    0    7   55.00000   60.00000  9.09%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Zero half: 1
#
# Explored 1 nodes (51 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.500000000000e+01, best bound 5.500000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1034 rows, 295 columns and 1992 nonzeros
# Model fingerprint: 0x492e5f53
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Found heuristic solution: objective -0.0000000
# Presolve removed 1017 rows and 240 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 55 columns, 110 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
# Found heuristic solution: objective 20.0000000
#
# Root relaxation: objective 4.500000e+01, 26 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.00000    0    5   20.00000   45.00000   125%     -    0s
# H    0     0                      40.0000000   45.00000  12.5%     -    0s
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#
# Explored 1 nodes (30 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 40 20 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1036 rows, 295 columns and 1994 nonzeros
# Model fingerprint: 0x33f223a3
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 40 (0.01s)
# Loaded MIP start from previous solve with objective 40
#
# Presolve removed 1019 rows and 240 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 55 columns, 110 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 4.500000e+01, 26 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0 infeasible    0        40.00000   40.00000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 40
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1038 rows, 295 columns and 1996 nonzeros
# Model fingerprint: 0xbe14d70e
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 40 (0.01s)
# Loaded MIP start from previous solve with objective 40
#
# Presolve removed 1021 rows and 240 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 55 columns, 110 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 4.500000e+01, 26 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0 infeasible    0        40.00000   40.00000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 40
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1040 rows, 295 columns and 1998 nonzeros
# Model fingerprint: 0x9639e16a
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 40 (0.01s)
# Loaded MIP start from previous solve with objective 40
#
# Presolve removed 1023 rows and 240 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 55 columns, 110 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 4.500000e+01, 26 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0   45.00000    0    5   40.00000   45.00000  12.5%     -    0s
#      0     0 infeasible    0        40.00000   40.00000  0.00%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 40
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1042 rows, 295 columns and 2000 nonzeros
# Model fingerprint: 0xba035ef4
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve did not produce a new incumbent solution
#
# Found heuristic solution: objective -0.0000000
# Presolve removed 1028 rows and 260 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 35 columns, 70 nonzeros
# Variable types: 0 continuous, 35 integer (35 binary)
# Found heuristic solution: objective 20.0000000
#
# Root relaxation: objective 2.666667e+01, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.66667    0    5   20.00000   26.66667  33.3%     -    0s
#      0     0 infeasible    0        20.00000   20.00000  0.00%     -    0s
#
# Explored 1 nodes (24 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 20 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1044 rows, 295 columns and 2002 nonzeros
# Model fingerprint: 0x7ea0a50d
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 20 (0.00s)
# Loaded MIP start from previous solve with objective 20
#
# Presolve removed 1033 rows and 270 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 25 columns, 50 nonzeros
# Variable types: 0 continuous, 25 integer (25 binary)
#
# Root relaxation: objective 2.666667e+01, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.66667    0    6   20.00000   26.66667  33.3%     -    0s
#      0     0 infeasible    0        20.00000   20.00000  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1046 rows, 295 columns and 2004 nonzeros
# Model fingerprint: 0x68f7271c
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 20 (0.00s)
# Loaded MIP start from previous solve with objective 20
#
# Presolve removed 1035 rows and 270 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 25 columns, 50 nonzeros
# Variable types: 0 continuous, 25 integer (25 binary)
#
# Root relaxation: objective 2.666667e+01, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.66667    0    6   20.00000   26.66667  33.3%     -    0s
#      0     0 infeasible    0        20.00000   20.00000  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Reset all parameters
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1048 rows, 295 columns and 2006 nonzeros
# Model fingerprint: 0xe37cd777
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# MIP start from previous solve produced solution with objective 20 (0.01s)
# Loaded MIP start from previous solve with objective 20
#
# Presolve removed 1037 rows and 270 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 25 columns, 50 nonzeros
# Variable types: 0 continuous, 25 integer (25 binary)
#
# Root relaxation: objective 2.666667e+01, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.66667    0    6   20.00000   26.66667  33.3%     -    0s
#      0     0 infeasible    0        20.00000   20.00000  0.00%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Reset all parameters

# %%
res.head()
# Out:
#    Benefice  longueur max  projets max
# 0      65.0           4.0          4.0
# 1      65.0           4.0          3.0
# 2      65.0           4.0          2.0
# 3      65.0           4.0          1.0
# 4      55.0           3.0          1.0

# %% [markdown]
# # Model optimisation

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

X, Y = np.meshgrid(res["projets max"], res["longueur max"])
Z = res["Benefice"]

X = np.array(res["projets max"])
Y = np.array(res["longueur max"])
Z = np.array(res["Benefice"])

# Plot the surface.
surf = ax.plot_trisurf(X, Y, Z, cmap = 'Spectral')

# Add a color bar which maps values to colors.
fig.colorbar(surf, pad=0.2)

ax.set_xlabel('projets max')
ax.set_ylabel('longueur max')
ax.set_zlabel('bénéfice')

fig.set_size_inches(7, 5)

if taille == "small":
    plt.savefig("results/sys_preference/small.png")
elif taille=="medium":
    plt.savefig("results/sys_preference/medium.png")
else:
    plt.savefig("results/sys_preference/large.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-0902b07287c2> in <module>
#       1 from mpl_toolkits.axes_grid1 import make_axes_locatable
#       2
# ----> 3 fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
#       4
#       5 X, Y = np.meshgrid(res["projets max"], res["longueur max"])
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1210     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1211                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1212                        gridspec_kw=gridspec_kw)
#    1213     return fig, axs
#    1214
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1573                 subplot_kw["sharex"] = shared_with[sharex]
#    1574                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1575                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1576
#    1577         # turn off redundant tick labeling
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1394         else:
#    1395             projection_class, kwargs, key = \
# -> 1396                 self._process_projection_requirements(*args, **kwargs)
#    1397
#    1398             # try to find the axes with this key in the stack
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in _process_projection_requirements(self, polar, projection, *args, **kwargs)
#    1118
#    1119         if isinstance(projection, str) or projection is None:
# -> 1120             projection_class = projections.get_projection_class(projection)
#    1121         elif hasattr(projection, '_as_mpl_axes'):
#    1122             projection_class, extra_kwargs = projection._as_mpl_axes()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
# ---> 60         raise ValueError("Unknown projection %r" % projection)
#      61
#      62
#
# ValueError: Unknown projection '3d'

# %%
# Verify model formulation

#nom = "results/"+taille+".lp"
#model.write(nom)

# Run optimization engine

model.optimize()
# Out:
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8257U CPU @ 1.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1048 rows, 295 columns and 2006 nonzeros
# Model fingerprint: 0xe37cd777
# Variable types: 25 continuous, 270 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
# Presolved: 11 rows, 25 columns, 50 nonzeros
#
# Continuing optimization...
#
#
# Explored 1 nodes (23 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%

# %%
## Print the values of all variables
# for v in model.getVars():
#     print(f"{v.VarName} = {v.X}")

# Pour voir quels sont les projets faits
# for j in range(nombre_projets):
#     v = model.getVarByName(f"u[{j}]")
#     if int(v.x) == 1:
#         print(f"la tâche {j} est faite")
#     else:
#         print(f"la tâche {j} n'est pas faite")

# %%
# Edt des employés et le détail de la réalisation de chaque tâche (de façon ordonnée)



schedules = []
tasks_performances = []
for i in range(nombre_qualifs):
    for j in range(nombre_projets):
        for k in range(nombre_employes):
            for n in range(horizon):
                v = model.getVarByName(f"x[{i},{j},{k},{n}]")
                if int(v.x) == 1:
                    schedules.append((map_employe_indice[k], n+1, map_job_indice[j], map_qualif_indice[i]))
                    tasks_performances.append((map_job_indice[j], map_qualif_indice[i], map_employe_indice[k], n+1))

schedules.sort()

tasks_performances.sort()

# Dates de début et de fin des tâches réalisees 
# (à n'étudier que lorsque longueur_max est mis en objectif, sinon les 
# variables dateDebut et dateFin ne sont pas assez contraintes pour prendre exactement le sens souhaité)

# for j in range(nombre_projets):
#     v = model.getVarByName(f"u[{j}]")
#     v1 = model.getVarByName(f"dateDebut[{j}]")
#     v2 = model.getVarByName(f"dateFin[{j}]")
#     if int(v.x) == 1:
#         print(f"la tâche {j} commence à la date {int(1+v1.x)} et finit à la date {int(1+v2.x)}")

# %%
df = pd.DataFrame(schedules, columns=['Nom', 'Jour', 'Projet', 'Qualification'])

print(df)

df['Affectation'] = df[['Projet', 'Qualification']].values.tolist()

df = df.pivot(index=['Nom'], 
                    columns=['Jour'],
                    values=['Affectation'])

df.fillna(0, inplace=True)

# Define a color map for the qualifications
color_map = {'A': 'lightgreen', 'B': 'yellow', 'C': 'pink'}

# Apply conditional formatting to the cells based on the qualifications
df.style.applymap(lambda x: 'background-color: {}'.format(color_map[x['Affectation'][1]]))

for x in df['Affectation'][1]:
    print(x)

df
# Out:
#       Nom  Jour Projet Qualification
# 0    Emma     1   Job1             C
# 1  Olivia     1   Job1             A
# 2  Olivia     2   Job1             B
# ['Job1', 'C']
# ['Job1', 'A']
#        Affectation
# Jour             1          2
# Nom
# Emma     [Job1, C]          0
# Olivia   [Job1, A]  [Job1, B]

# %%
schedules

# %%
from utils.show_planning import show_planning

df = pd.DataFrame(schedules, columns=['Nom', 'Jour', 'Projet', 'Qualification'])
show_planning(df)

# %%
## Avec seulement le bénéfice à optimiser
## Commenter lors de la recherche de solutions non dominées

# if taille == "small":
#     df.to_json(r'results/benefice/small_benefice.json')
# elif taille=="medium":
#     df.to_json(r'results/benefice/medium_benefice.json')
# else:
#     df.to_json(r'results/benefice/large_benefice.json')

# %%
model.objVal

# %%
####################
#### RESULTS #######
####################


## Bénéfice totale (small) = 65
## Bénéfice totale (medium) = 413
## Bénéfice totale (large) = 817
